# %% [markdown]
# Scrape at least 400 full reviews and ratings from Yelp for a restaurant that has mixed reviews. (10 pts.)
#
# Clean and pre-process the data. (5 pts.)
#
# Develop a Word2Vec model using the reviews. (5 pts.)
#
# Identify words that are most similar to 3 items on the restaurant menu using the Word2Vec model. Comment on whether the similar words make sense. (5 pts.)

# %%
import pandas as pd

df=pd.read_csv('/content/panchos_burritos.csv')

# %%
df
# Out:
#             name  rating         location          date  \
# 0       Sarah P.       3    Montclair, NJ   Mar 7, 2023
# 1      Joseph F.       4  New Milford, NJ  Dec 23, 2023
# 2        Dena H.       3    Englewood, NJ  Jan 26, 2023
# 3       Ellie O.       4     Westwood, NJ  Jan 12, 2024
# 4       Lenny G.       3       Verona, NJ  Jan 14, 2023
# ..           ...     ...              ...           ...
# 633     Janis H.       2  New Milford, NJ  Jun 16, 2010
# 634      Rita S.       5    Manhattan, NY   Mar 4, 2012
# 635         C B.       5   Wood-Ridge, NJ  Sep 19, 2013
# 636  Michelle S.       3  New Milford, NJ  Jan 31, 2014
# 637    Marnie M.       1      Closter, NJ  Mar 20, 2014
#
#                                                   body sentiment
# 0    Let's start with the good - the ambiance and s...  Negative
# 1    Pancho's food and service are very good BUT ri...  Positive
# 2    I really loved the vibes of this place and the...  Negative
# 3    We have way too much fun when we come here! Fo...  Positive
# 4    The food is pretty mediocre and is way overpri...  Negative
# ..                                                 ...       ...
# 633  This place is great for drinks, guac and chips...  Negative
# 634  The bean and cheese burritos are the best I've...  Positive
# 635  my coworker brought me here one afternoon. it ...  Positive
# 636  ive had better.....food is pretty good, staff ...  Negative
# 637  My family has always been a loyal customer of ...  Negative
#
# [638 rows x 6 columns]

# %%
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from gensim.models import Word2Vec

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def clean_text(text):
    text = text.lower()
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    cleaned_text = ' '.join(tokens)
    return tokens

cleaned_reviews = df['body'].apply(clean_text).tolist()

w2v_model = Word2Vec(sentences=cleaned_reviews, vector_size=100, window=5, min_count=1, workers=4)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print(cleaned_reviews)
# Out:
# [['let', 'start', 'good', 'ambiance', 'service', 'place', 'definitely', '1010', 'multiple', 'giant', 'screen', 'surrounding', 'table', 'play', 'music', 'video', 'well', 'dj', 'booth', 'assume', 'place', 'turn', 'fun', 'clurb', 'weekend', 'server', 'constantly', 'coming', 'around', 'asking', 'needed', 'anything', 'clearing', 'table', 'food', 'drink', 'came', 'quickly', 'parking', 'side', 'building', 'drove', '10', 'mile', 'place', 'ad', 'came', 'ig', 'happy', 'hour', 'day', 'everyday', 'would', 'catch', 'anyones', 'attention', 'prepared', 'price', 'everything', 'else', 'yes', 'certain', 'drink', '5', 'limited', 'one', 'option', 'frozen', 'classic', 'marg', 'asked', 'could', 'get', 'regularon', 'rock', 'said', 'would', '16', 'dont', 'go', 'asking', 'substitution', 'unless', 'youre', 'ready', 'pay', 'would', 'recommend', 'sangria', 'frozen', 'marg', 'happy', 'hour', 'menu', 'took', 'pic', 'menu', 'could', 'see', 'price', 'food', '20', '2', 'taco', 'burrito', 'side', '21', 'small', 'veggie', 'enchilada', 'side', '22', 'look', 'pic', 'menu', 'mean', 'anything', '12', 'ended', 'ordering', 'quesadilla', 'happened', 'cheapest', 'thing', 'menu', 'still', '17', 'dont', 'mind', 'paying', 'amount', 'food', 'average', 'like', 'something', 'could', 'get', 'taco', 'truck', 'ny', 'half', 'price', 'appreciate', 'least', 'gave', 'free', 'chip', 'salsa', 'sat', 'bottom', 'line', 'would', 'return', 'yes', 'probably', 'drink', 'happy', 'hour', 'deal', 'like', 'taco', 'tuesday', 'bottomless', 'sunday', 'brunch', 'change', 'price', 'match', 'qualityamount', 'food', 'get'], ['panchos', 'food', 'service', 'good', 'ridiculously', 'expensive', '45', 'grill', 'shrimp', 'burrito', 'piece', 'tres', 'lech', 'cake', '2', 'can', 'lipton', 'ice', 'tea'], ['really', 'loved', 'vibe', 'place', 'music', 'also', 'day', 'long', 'happy', 'hour', 'drink', 'great', '5', 'margarita', 'hit', 'spot', 'disappointed', 'food', 'pretty', 'expensive', 'best', 'quality', 'ordered', 'chicken', 'nacho', 'came', '29', 'expensive', 'nacho', 'ever', 'also', 'ordered', 'taco', '4', 'taco', 'wasnt', 'fan', 'tortilla', 'staff', 'nice', 'accommodating', 'would', 'probably', 'give', 'place', 'another', 'try', 'summer', 'drink', 'likely', 'food'], ['way', 'much', 'fun', 'come', 'food', 'delicious', 'drink', 'good', 'dj', 'play', 'like', 'negative', 'thing', 'would', 'say', 'cut', 'back', 'strobe', 'light', 'fog', 'machine'], ['food', 'pretty', 'mediocre', 'way', 'overpriced', 'ambiance', 'fun', 'saturday', 'night', 'service', 'really', 'good'], ['great', 'spot', 'wan', 'na', 'come', 'watch', 'football', 'game', 'enjoy', 'cheap', 'drink', 'food', 'sub', 'par', 'best', 'menu', 'item', 'taste', 'frozen', 'theyre', 'extremely', 'overpriced', 'however', 'drink', 'compared', 'place', 'youre', 'going', 'drink', 'great', 'place', 'want', 'good', 'mexican', 'food', 'wouldnt', 'necessarily', 'come', 'inside', 'nice', 'though', 'cool', 'date', 'nice', 'spot'], ['went', 'small', 'group', 'dinner', 'extremely', 'overpriced', 'drink', 'food', 'good', 'djclub', 'atmosphere', 'weekend', 'night', '9pm', 'scene'], ['sunday', 'panchos', 'lit', 'dj', 'entertainment', 'sunday', 'turning', 'restaurant', 'interior', 'full', 'club', 'mode', 'cool', 'ate', 'outdoor', 'dining', 'area', 'wonderful', 'spaced', 'service', 'server', 'jessica', 'spot', 'genuinely', 'friendly', 'attentive', 'food', 'cocktail', 'served', 'without', 'delay', 'fresh', 'hot', 'unison', 'drink', 'point', 'miami', 'vice', 'delicious', 'want', 'little', 'kick', 'go', 'órale', 'guey', 'yum', 'food', 'incredibly', 'delicious', 'chicken', 'quesadilla', 'perfect', 'filling', 'need', 'side', 'flavor', 'carne', 'asada', 'bowl', 'mole', 'outstanding', 'overall', 'solid', 'choice', 'local', 'mexican', 'would', 'go', 'back', 'also', 'order', 'delivery', 'available', 'great', 'experience', 'around'], ['food', 'disgusting', 'sitting', 'soggy', 'service', 'good', 'worth', 'going', 'back'], ['decided', 'come', 'back', 'see', 'thing', 'changed', 'know', 'ha ...

# %%
w2v_model.wv.most_similar(positive=['burrito'], topn=5)
# Out:
# [('got', 0.9998496770858765),
#  ('chicken', 0.9998348355293274),
#  ('ordered', 0.999828040599823),
#  ('taco', 0.9998267889022827),
#  ('food', 0.999812126159668)]

# %%
w2v_model.wv.most_similar(positive=['margarita'], topn=5)
# Out:
# [('would', 0.9997919797897339),
#  ('drink', 0.999788224697113),
#  ('like', 0.999782919883728),
#  ('im', 0.9997766017913818),
#  ('go', 0.9997730255126953)]

# %%
w2v_model.wv.most_similar(positive=['guacamole'], topn=5)
# Out:
# [('food', 0.9997414350509644),
#  ('burrito', 0.9997348785400391),
#  ('got', 0.9997231364250183),
#  ('drink', 0.9997216463088989),
#  ('taco', 0.9997212290763855)]

# %% [markdown]
# Results were extremely high but words seemed accurate for burrito but other words looked random. Especially 'margarita' only had drink that seemed fitting.

# %% [markdown]
# I adjusted parameters because the words seemed a little basic and the results were too high. Results remained high scores but the words seemed such more accurate.

# %%
w2v_model = Word2Vec(sentences=cleaned_reviews, vector_size=150, window=10, min_count=5, workers=4,epochs=10)

# %%
w2v_model.wv.most_similar(positive=['burrito'], topn=5)
# Out:
# [('steak', 0.9991416931152344),
#  ('chicken', 0.9990193247795105),
#  ('taco', 0.9985199570655823),
#  ('cheese', 0.9982560873031616),
#  ('rice', 0.9975676536560059)]

# %%
w2v_model.wv.most_similar(positive=['margarita'], topn=5)
# Out:
# [('super', 0.9990503787994385),
#  ('amazing', 0.9982589483261108),
#  ('frozen', 0.9982538819313049),
#  ('bulldog', 0.9981478452682495),
#  ('love', 0.9975672960281372)]

# %%
w2v_model.wv.most_similar(positive=['guacamole'], topn=5)
# Out:
# [('bowl', 0.9991681575775146),
#  ('cream', 0.9989661574363708),
#  ('sour', 0.9989660978317261),
#  ('grilled', 0.9989659786224365),
#  ('sauce', 0.9989293217658997)]

# %% [markdown]
# These results were much stronger and fit the words better. Burrito had all ingredients and taco which is similar. Margarita had great descriptions specifically fitting their frozen bulldog margarita menu item. Finally guacamole had much more fitting towards being a dip as opposed to how it was prior to parameter adjustment. It leaned toward sauce and sour cream which makes sense.
